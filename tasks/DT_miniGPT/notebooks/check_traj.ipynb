# %%
import numpy as np

# %%
sample = np.load('/home/qid/minghanli/HC3D_simulator/tasks/DT_miniGPT/trajs/val_seen_trajs_teacher_right_left_mix_teacher.pkl', allow_pickle=True)

# %%
first_sample = sample[0].copy()
del sample

# %%
first_sample
# Out:
# {'instr_id': '1127_0',
#  'path': [('be1a38f2bec74de79395d0a938234d38', 0.0, 0.0),
#   ('be1a38f2bec74de79395d0a938234d38', 0.5235987755982988, 0.0),
#   ('be1a38f2bec74de79395d0a938234d38', 1.0471975511965976, 0.0),
#   ('be1a38f2bec74de79395d0a938234d38', 1.5707963267948966, 0.0),
#   ('be1a38f2bec74de79395d0a938234d38',
#    1.5707963267948966,
#    -0.5235987755982988),
#   ('63333423642f49caac4871521e93cc45',
#    1.5707963267948966,
#    -0.5235987755982988),
#   ('5965958b0a55454d88d45f21d97bc3fc',
#    1.5707963267948966,
#    -0.5235987755982988),
#   ('5965958b0a55454d88d45f21d97bc3fc', 1.5707963267948966, 0.0),
#   ('5965958b0a55454d88d45f21d97bc3fc', 2.0943951023931953, 0.0),
#   ('5965958b0a55454d88d45f21d97bc3fc', 2.617993877991494, 0.0),
#   ('5965958b0a55454d88d45f21d97bc3fc', 3.141592653589793, 0.0),
#   ('5965958b0a55454d88d45f21d97bc3fc', 3.665191429188092, 0.0),
#   ('5965958b0a55454d88d45f21d97bc3fc', 4.1887902047863905, 0.0),
# ...
