# %%
import numpy as np

# %%
sample = np.load('/home/qid/minghanli/HC3D_simulator/tasks/HC/trajs/teacher/train_trajs_0_teacher.pkl', allow_pickle=True)

# %%
first_sample = sample[0].copy()
del sample

# %%
first_sample
# Out:
# {'instr_id': '2571_0',
#  'path': [('d65b6505904448d1940e679c9a098047', 1.5707963267948966, 0.0),
#   ('d65b6505904448d1940e679c9a098047', 2.0943951023931953, 0.0),
#   ('d65b6505904448d1940e679c9a098047', 2.617993877991494, 0.0),
#   ('701f7128272a4bb2acd9dbd89b5cdf6f', 2.617993877991494, 0.0),
#   ('701f7128272a4bb2acd9dbd89b5cdf6f', 3.141592653589793, 0.0),
#   ('c429b363fd3145fe8a7631bbe9644066', 3.141592653589793, 0.0),
#   ('c429b363fd3145fe8a7631bbe9644066', 3.665191429188092, 0.0),
#   ('c429b363fd3145fe8a7631bbe9644066', 4.1887902047863905, 0.0),
#   ('1a41339ece1846eda6a924cdb4c417dd', 4.1887902047863905, 0.0),
#   ('1a41339ece1846eda6a924cdb4c417dd', 4.71238898038469, 0.0),
#   ('08c774f20c984008882da2b8547850eb', 4.71238898038469, 0.0)],
#  'teacher_actions': [0, 0, 5, 0, 5, 0, 0, 5, 0, 5, 4],
#  'student_actions': [0, 0, 5, 0, 5, 0, 0, 5, 0, 5, 4],
#  'unique_path': ['d65b6505904448d1940e679c9a098047',
#   '701f7128272a4bb2acd9dbd89b5cdf6f',
# ...
